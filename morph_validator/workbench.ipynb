# %%
""""""
import itertools
import logging
from enum import Enum
from pathlib import Path

import neurom as nm
import numpy as np
import pandas as pd
from lxml import etree
from neurom import NeuriteType
from scipy import stats

L = logging.getLogger(__name__)
pd.options.display.width = 0


class DISCRETE_FEATURE_NAMES(Enum):
    LEN = 'total_length'
    SURFACE_AREA = 'total_area_per_neurite'
    VOLUMES = 'neurite_volumes'
    NUMBER_OF_SECTIONS = 'number_of_sections'
    NUMBER_OF_BIFURCATIONS = 'number_of_bifurcations'
    NUMBER_OF_TERMINATIONS = 'number_of_terminations'


class CONTINUOUS_FEATURE_NAMES(Enum):
    SECTION_LEN = 'section_lengths'
    SECTION_RADIAL_DISTANCES = 'section_radial_distances'
    SECTION_PATH_DISTANCES = 'section_path_distances'
    PARTITION_ASYMMETRY = 'partition_asymmetry'
    SEGMENT_RADII = 'segment_radii'


NEURITES = (NeuriteType.soma,
            NeuriteType.axon,
            NeuriteType.basal_dendrite,
            NeuriteType.apical_dendrite,
            NeuriteType.undefined,)
NEURITE_NAMES = [type.name for type in NEURITES]

CUSTOM_FEATURE_LOAD = {
    DISCRETE_FEATURE_NAMES.SURFACE_AREA.value: {
        NeuriteType.soma.name: lambda neuron: nm.get('soma_surface_areas', neuron),
    }
}

MORPH_FILETYPES = ['.h5', '.swc', '.asc']


class Features(object):
    class INDEX(Enum):
        MTYPE = 'mtype'
        FILENAME = 'filename'
        NEURITE = 'neurite'

    _INDEX_NAMES = [index.value for index in INDEX]

    def __init__(self, index, discrete, continuous):
        self.discrete = pd.concat(discrete, keys=index, names=self._INDEX_NAMES)
        self.continuous = pd.concat(continuous, keys=index, names=self._INDEX_NAMES)


def get_discrete_features(neuron) -> pd.DataFrame:
    feature_names = [name.value for name in DISCRETE_FEATURE_NAMES]
    df = get_features(neuron, feature_names)
    df = df.applymap(np.sum)
    df.loc[NeuriteType.all.name] = df.sum()
    return df


def get_continuous_features(neuron) -> pd.DataFrame:
    feature_names = [name.value for name in CONTINUOUS_FEATURE_NAMES]
    df = get_features(neuron, feature_names)
    # `np.concatenate(x).tolist()` is used instead `np.concatenate(x)` to treat the return object
    # as a single value. Without it pandas treat it as a Series and tries to broadcast it.
    # When `np.concatenate(x).tolist()` returns a list of length equal to len(df) => may be an error
    df.loc[NeuriteType.all.name] = df.aggregate(lambda x: np.concatenate(x).tolist())
    return df


def get_features(neuron, feature_names) -> pd.DataFrame:
    df = pd.DataFrame(index=NEURITE_NAMES, columns=feature_names)
    for neurite, feature_name in itertools.product(NEURITES, feature_names):
        val = None
        if feature_name in CUSTOM_FEATURE_LOAD:
            if neurite.name in CUSTOM_FEATURE_LOAD[feature_name]:
                val = CUSTOM_FEATURE_LOAD[feature_name][neurite.name](neuron)
        if val is None:
            val = nm.get(feature_name, neuron, neurite_type=neurite)
        df.loc[neurite.name, feature_name] = val.tolist()
    return df


def get_mtype_dict(db_file: Path) -> dict:
    root = etree.parse(str(db_file)).getroot()
    mtype_dict = {}
    for morphology in root.iterfind('.//morphology'):
        name = morphology.findtext('name')
        if not name:
            L.warning('Empty morphology name in %s', db_file)
        mtype = morphology.findtext('mtype')
        if not mtype:
            L.warning('Empty morphology mtype in %s', db_file)
        if name in mtype_dict and mtype_dict[name] != mtype:
            L.warning('Multiple mtypes %s %s for %s', mtype, mtype_dict[name], name)
        mtype_dict[name] = mtype
    return mtype_dict


def get_valid_morph_features(morph_dirpath: Path) -> Features:
    if not morph_dirpath.is_dir():
        raise ValueError(
            '"{}" must be a directory with morphology files'.format(morph_dirpath))
    mtype_dict = get_mtype_dict(morph_dirpath.joinpath('neuronDB.xml'))
    index, discrete, continuous = [], [], []
    for file in morph_dirpath.iterdir():
        if file.suffix in MORPH_FILETYPES:
            neuron = nm.load_neuron(str(file))
            mtype = mtype_dict[neuron.name]
            index.append((mtype, neuron.name))
            discrete.append(get_discrete_features(neuron))
            continuous.append(get_continuous_features(neuron))
    return Features(index, discrete, continuous)


def get_test_morph_features(morph_dirpath: Path) -> Features:
    if not morph_dirpath.is_dir():
        raise ValueError(
            '"{}" must be a directory'.format(morph_dirpath))
    index, discrete, continuous = [], [], []
    for mtype_dir in morph_dirpath.iterdir():
        mtype = mtype_dir.name
        for file in mtype_dir.iterdir():
            if file.suffix in MORPH_FILETYPES:
                neuron = nm.load_neuron(str(file))
                index.append((mtype, neuron.name))
                discrete.append(get_discrete_features(neuron))
                continuous.append(get_continuous_features(neuron))
    return Features(index, discrete, continuous)


def ks_2samp(a, b):
    return stats.ks_2samp(a, b) + (len(a),)


def get_ks_of_valid_features(valid_features):
    def ks_valid(feature_series):
        def ks(a, b):
            b = np.concatenate(b)
            if a and b.size:
                return ks_2samp(a, b)

        fs_list = feature_series.to_list()
        return [ks(fs_list[i], fs_list[:i] + fs_list[i + 1:]) for i in range(0, len(fs_list))]

    return valid_features.continuous \
        .groupby([Features.INDEX.MTYPE.value, Features.INDEX.NEURITE.value]) \
        .transform(ks_valid)


def get_ks_of_test_features(test_features, valid_features):
    def ks_test(file_series):
        mtype = file_series.index.get_level_values('mtype').unique()[0]
        if not mtype in neurite_feature_distr.index.levels[0]:
            return None
        mtype_series = neurite_feature_distr.loc[mtype][file_series.name]
        return [ks_2samp(fm[0], fm[1])
                if fm[0] and fm[1] else None for fm in zip(file_series, mtype_series)]

    neurite_feature_distr = valid_features.continuous \
        .groupby([Features.INDEX.MTYPE.value, Features.INDEX.NEURITE.value]) \
        .agg(lambda feature: np.concatenate(feature).tolist())

    return test_features.continuous \
        .groupby([Features.INDEX.MTYPE.value, Features.INDEX.FILENAME.value]).transform(ks_test)


def discrete_z_score(valid_features: Features, test_features: Features):
    valid_mean = valid_features.discrete.groupby(
        [Features.INDEX.MTYPE.value, Features.INDEX.NEURITE.value]).mean()
    valid_std = valid_features.discrete.groupby(
        [Features.INDEX.MTYPE.value, Features.INDEX.NEURITE.value]).std()
    return ((test_features.discrete - valid_mean) / valid_std).dropna(how='all')


def discrete_report(z_score: pd.DataFrame, p_value=0.05):
    assert 0. <= p_value <= 1.
    threshold = np.abs(stats.norm.ppf(p_value / 2.))
    # some cells in z_score are NaN so we use `failed_neurites` + `any`
    # instead of `valid_neurites` + `all`.
    failed_neurites = (z_score.abs() > threshold).any(axis=1)
    return (~failed_neurites).groupby(['filename', 'mtype']).all()

# %%
# valid_features = build_valid_morphologies(Path('../tests/data/morphologies/valid/all'))
# import shutil
# L23_BTC
# filenames = set(valid_features.discrete.loc['L5_TPC'].index.get_level_values('filename'))
# filenames
# for filename in filenames:
#     shutil.copy2(
#         '/home/sanin/workspace/morph-validator/tests/data/morphologies/valid/all/' + filename + '.h5',
#         '/home/sanin/workspace/morph-validator/tests/data/morphologies/valid/mini')

# %%
valid_features = build_valid_morphologies(Path('../tests/data/morphologies/valid/mini'))

# %%
test_features = build_test_morphologies(Path('../tests/data/morphologies/test'))

# %%
z_score = discrete_z_score(valid_features, test_features)
discrete_report(z_score)
# Out:
# filename        mtype
# C040426         L5_MC      True
# C050896A-I      L5_MC      True
# C290500C-I4     L5_MC      True
# mtC031100A_idB  L23_BTC    True
# dtype: bool

# %%
valid_ks = get_ks_of_valid_features(valid_features)
valid_ks
# Out:
#                                                                                      section_lengths  \
# mtype   filename                  neurite
# L23_BTC C210401C                  soma                                                          None
#                                   axon              (0.19442848965980639, 4.22459922599927e-09, 281)
#                                   basal_dendrite      (0.14330143540669857, 0.22719573169336205, 55)
#                                   apical_dendrite                                               None
#                                   undefined                                                     None
# ...                                                                                              ...
# L5_TPC  rat_20170523_E1_LH2_cell1 axon               (0.2559411711954085, 9.89319737243477e-13, 245)
#                                   basal_dendrite       (0.09636650868878358, 0.5597696267161392, 90)
#                                   apical_dendrite     (0.15895610913404506, 0.04322940735041114, 99)
#                                   undefined                                                     None
#                                   all              (0.22594127463006553, 3.9968028886505635e-15, ...
#
#                                                                             section_radial_distances  \
# mtype   filename                  neurite
# L23_BTC C210401C                  soma                                                          None
#                                   axon             (0.47410397431749746, 2.738166969868195e-51, 281)
#                                   basal_dendrite       (0.09614234449760765, 0.7011390763718283, 55)
#                                   apical_dendrite                                               None
#                                   undefined                                                     None
# ...                                                                                              ...
# L5_TPC  rat_20170523_E1_LH2_cell1 axon                (0.1038676864342724, 0.01877043125658573, 245)
#                                   basal_dendrite      (0.18304370721432334, 0.02484402781049544, 90)
#                                   apical_dendrite     (0.17071066537258708, 0.02419461006903345, 99)
#                                   undefined                                                     None
#                                   all              (0.09714219407883831, 0.0020929689331080636, 434)
#
#                                                                               section_path_distances  \
# mtype   filename                  neurite
# L23_BTC C210401C                  soma                                                          None
#                                   axon             (0.43307667421546425, 7.238951991722821e-43, 281)
#                                   basal_dendrite       (0.09973086124401914, 0.6577285330497541, 55)
#                                   apical_dendrite                                               None
#                                   undefined                                                     None
# ...                                                                                              ...
# L5_TPC  rat_20170523_E1_LH2_cell1 axon               (0.1189335998052705, 0.004432607154251644, 245)
#                                   basal_dendrite        (0.1291205897840969, 0.2193805393354571, 90)
#                                   apical_dendrite      (0.08044861425644344, 0.6930934989347561, 99)
#                                   undefined                                                     None
#                                   all              (0.12965664334891533, 9.972688787107664e-06, 434)
#
#                                                                                 partition_asymmetry  \
# mtype   filename                  neurite
# L23_BTC C210401C                  soma                                                         None
#                                   axon               (0.03971466489714665, 0.9830556838212886, 137)
#                                   basal_dendrite      (0.06661971830985916, 0.9997144455938968, 25)
#                                   apical_dendrite                                              None
#                                   undefined                                                    None
# ...                                                                                             ...
# L5_TPC  rat_20170523_E1_LH2_cell1 axon             (0.3323538509124652, 6.831069043755633e-11, 122)
#                                   basal_dendrite       (0.16666666666666666, 0.369727037212353, 40)
#                                   apical_dendrite     (0.11921891058581706, 0.6295642596457991, 49)
#                                   undefined                                                    None
#                                   all              (0.2645009892789767, 2.733124837561718e-11, 211)
#
#                                                                                        segment_radii
# mtype   filename                  neurite
# L23_BTC C210401C                  soma                                                          None
#                                   axon                               (0.6596349807414149, 0.0, 4800)
#                                   basal_dendrite   (0.2975399691118329, 1.5065678415352957e-139, ...
#                                   apical_dendrite                                               None
#                                   undefined                                                     None
# ...                                                                                              ...
# L5_TPC  rat_20170523_E1_LH2_cell1 axon             (0.043004741005777, 5.823997517169108e-20, 16889)
#                                   basal_dendrite                     (0.4892864943464956, 0.0, 5809)
#                                   apical_dendrite                    (0.4764837485413065, 0.0, 8633)
#                                   undefined                                                     None
#                                   all                              (0.26554088371933027, 0.0, 31331)
#
# [144 rows x 5 columns]

# %%
test_ks = get_ks_of_test_features(test_features, valid_features)
test_ks
# Out:
#                                                                           section_lengths  \
# mtype   filename       neurite
# L5_MC   C040426        soma                                                          None
#                        axon              (0.1391161763750893, 0.0003542457426518597, 232)
#                        basal_dendrite      (0.24360859266519644, 0.03865565996219866, 33)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all              (0.13981548001663704, 9.371494500731714e-05, 265)
#         C050896A-I     soma                                                          None
#                        axon              (0.1119301375651439, 0.0004350034932669722, 361)
#                        basal_dendrite        (0.2169811320754717, 0.0070074163070728, 63)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all              (0.10897077173214353, 0.00016932483195619685, ...
#         C290500C-I4    soma                                                          None
#                        axon             (0.13131495728967818, 0.00013861030867812207, ...
#                        basal_dendrite      (0.18859394725169742, 0.01062991821665793, 79)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all               (0.08058805783610232, 0.020984740765956467, 372)
# Unknown ca3b-N2.CNG    soma                                                          None
#                        axon                                                          None
#                        basal_dendrite                                                None
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all                                                           None
# L23_BTC mtC031100A_idB soma                                                          None
#                        axon             (0.14393153526970953, 2.6174006673818084e-05, ...
#                        basal_dendrite      (0.16461969403145874, 0.07821517246657317, 63)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all              (0.11590694308109666, 0.0002863598345367313, 351)
#
#                                                                  section_radial_distances  \
# mtype   filename       neurite
# L5_MC   C040426        soma                                                          None
#                        axon             (0.16988927852457952, 5.080399893553356e-06, 232)
#                        basal_dendrite    (0.30727762803234504, 0.0038183191843642605, 33)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all              (0.13848073505501568, 0.0001132425319960717, 265)
#         C050896A-I     soma                                                          None
#                        axon             (0.3124096853790736, 1.2433381212604616e-28, 361)
#                        basal_dendrite      (0.16636717580113808, 0.07104325192253647, 63)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all              (0.2660112678186562, 1.9125358041727777e-24, 424)
#         C290500C-I4    soma                                                          None
#                        axon              (0.15666718086166226, 2.42616763423964e-06, 293)
#                        basal_dendrite   (0.31079190692278824, 1.2788339069924604e-06, 79)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all              (0.1361960480099985, 4.6037502710039035e-06, 372)
# Unknown ca3b-N2.CNG    soma                                                          None
#                        axon                                                          None
#                        basal_dendrite                                                None
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all                                                           None
# L23_BTC mtC031100A_idB soma                                                          None
#                        axon              (0.08964384508990318, 0.025205742401941844, 288)
#                        basal_dendrite      (0.2587804352510235, 0.000690319752312929, 63)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all               (0.07949972543909256, 0.030720156373627905, 351)
#
#                                                                    section_path_distances  \
# mtype   filename       neurite
# L5_MC   C040426        soma                                                          None
#                        axon              (0.22105331515033444, 6.41658615130325e-10, 232)
#                        basal_dendrite      (0.353099730458221, 0.0005027684985040581, 33)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all              (0.18349529247173593, 6.902217952742262e-08, 265)
#         C050896A-I     soma                                                          None
#                        axon             (0.19734103322534705, 7.940093027514195e-12, 361)
#                        basal_dendrite      (0.15633423180592992, 0.10447936807767644, 63)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all               (0.16804741558588876, 5.19133697608874e-10, 424)
#         C290500C-I4    soma                                                          None
#                        axon                (0.05345539037041322, 0.3992653474644552, 293)
#                        basal_dendrite    (0.29461940018424376, 5.518385634450951e-06, 79)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all               (0.08852543797271964, 0.008219349395597653, 372)
# Unknown ca3b-N2.CNG    soma                                                          None
#                        axon                                                          None
#                        basal_dendrite                                                None
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all                                                           None
# L23_BTC mtC031100A_idB soma                                                          None
#                        axon              (0.381108805901337, 3.1105031063974874e-34, 288)
#                        basal_dendrite   (0.31616749263808086, 1.3114405061576129e-05, 63)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all              (0.29902614412461725, 1.0114766946383423e-25, ...
#
#                                                                       partition_asymmetry  \
# mtype   filename       neurite
# L5_MC   C040426        soma                                                          None
#                        axon                (0.10625078134766845, 0.1613410038856401, 114)
#                        basal_dendrite       (0.22235067437379577, 0.4118872551781123, 15)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all                (0.07670338637290902, 0.44689887051477006, 129)
#         C050896A-I     soma                                                          None
#                        axon             (0.14253101082079705, 0.0021007994274948594, 180)
#                        basal_dendrite       (0.07109826589595376, 0.9970215227837695, 30)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all               (0.12529579763361892, 0.004158276054763821, 210)
#         C290500C-I4    soma                                                          None
#                        axon               (0.08431653271727459, 0.26980889042844125, 146)
#                        basal_dendrite      (0.18116823851536357, 0.18508081269010157, 38)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all                 (0.03848030085324535, 0.9525555165154443, 184)
# Unknown ca3b-N2.CNG    soma                                                          None
#                        axon                                                          None
#                        basal_dendrite                                                None
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all                                                           None
# L23_BTC mtC031100A_idB soma                                                          None
#                        axon                (0.03778389896575022, 0.9878169881754406, 142)
#                        basal_dendrite       (0.10064724919093851, 0.9166060939740241, 30)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all                 (0.04194691011828206, 0.9294646481519738, 172)
#
#                                                                             segment_radii
# mtype   filename       neurite
# L5_MC   C040426        soma                                                          None
#                        axon                                (0.702871914223569, 0.0, 5868)
#                        basal_dendrite                    (0.35228145440504416, 0.0, 4245)
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all                               (0.5943902112383981, 0.0, 10113)
#         C050896A-I     soma                                                          None
#                        axon                              (0.48260451374545305, 0.0, 3093)
#                        basal_dendrite   (0.17007851927989798, 1.9743039526774792e-91, ...
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all                                (0.5598261131799371, 0.0, 7512)
#         C290500C-I4    soma                                                          None
#                        axon                               (0.8684561871969644, 0.0, 4287)
#                        basal_dendrite   (0.23124863525002215, 8.134510376654792e-163, ...
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all                                (0.7288115411099936, 0.0, 8520)
# Unknown ca3b-N2.CNG    soma                                                          None
#                        axon                                                          None
#                        basal_dendrite                                                None
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all                                                           None
# L23_BTC mtC031100A_idB soma                                                          None
#                        axon             (0.1981728000482429, 4.030894406386304e-247, 8...
#                        basal_dendrite   (0.27453514229907483, 2.328022231385344e-282, ...
#                        apical_dendrite                                               None
#                        undefined                                                     None
#                        all              (0.1634009438356353, 3.0941908618205627e-273, ...

# %%
valid_ks.groupby(['mtype', 'neurite']).apply(lambda x: print(x, '@@@@@@@@'))
# Out:
#                                  section_lengths section_radial_distances  \
# mtype   filename         neurite
# L23_BTC C210401C         soma               None                     None
#         mtC020502A_idA   soma               None                     None
#         mtC031100A_idB   soma               None                     None
#         C200199B-I4      soma               None                     None
#         C190898A-I1      soma               None                     None
#         mtC061100A_idC   soma               None                     None
#         C220797A-I2      soma               None                     None
#         mtC121100B_idJ   soma               None                     None
#         mtC240300A_idB   soma               None                     None
#         mtC020200_14_idA soma               None                     None
#
#                                  section_path_distances partition_asymmetry  \
# mtype   filename         neurite
# L23_BTC C210401C         soma                      None                None
#         mtC020502A_idA   soma                      None                None
#         mtC031100A_idB   soma                      None                None
#         C200199B-I4      soma                      None                None
#         C190898A-I1      soma                      None                None
#         mtC061100A_idC   soma                      None                None
#         C220797A-I2      soma                      None                None
#         mtC121100B_idJ   soma                      None                None
#         mtC240300A_idB   soma                      None                None
#         mtC020200_14_idA soma                      None                None
#
#                                  segment_radii
# mtype   filename         neurite
# L23_BTC C210401C         soma             None
#         mtC020502A_idA   soma             None
#         mtC031100A_idB   soma             None
#         C200199B-I4      soma             None
#         C190898A-I1      soma             None
#         mtC061100A_idC   soma             None
#         C220797A-I2      soma             None
#         mtC121100B_idJ   soma             None
#         mtC240300A_idB   soma             None
#         mtC020200_14_idA soma             None   @@@@@@@@
#                                                                     section_lengths  \
# mtype   filename         neurite
# L23_BTC C210401C         axon      (0.19442848965980639, 4.22459922599927e-09, 281)
#         mtC020502A_idA   axon      (0.14488519685185702, 0.005076493821599692, 145)
#         mtC031100A_idB   axon      (0.1502983422627449, 9.737930276809692e-06, 289)
#         C200199B-I4      axon     (0.1618869979709181, 1.2568406196900028e-06, 291)
#         C190898A-I1      axon     (0.09286053923333457, 0.0018770212530289099, 453)
#         mtC061100A_idC   axon     (0.23958864375494418, 2.0026753588808788e-09, ...
#         C220797A-I2      axon       (0.042714148596501536, 0.7017253999353918, 286)
#         mtC121100B_idJ   axon       (0.07517438963627304, 0.09319556120166705, 288)
#         mtC240300A_idB   axon     (0.05641847468770546, 0.011140304217504005, 1152)
#         mtC020200_14_idA axon     (0.23122876444629298, 4.0767570334294826e-20, ...
#
#                                                            section_radial_distances  \
# mtype   filename         neurite
# L23_BTC C210401C         axon     (0.47410397431749746, 2.738166969868195e-51, 281)
#         mtC020502A_idA   axon     (0.1915888458357725, 5.8270726076115054e-05, 145)
#         mtC031100A_idB   axon       (0.09670441174045435, 0.01250331295034146, 289)
#         C200199B-I4      axon      (0.1691955485509656, 3.329310911404093e-07, 291)
#         C190898A-I1      axon     (0.24040662731689152, 1.705370511817769e-20, 453)
#         mtC061100A_idC   axon     (0.26667252644223727, 1.3402501330972427e-11, ...
#         C220797A-I2      axon     (0.16279602750190986, 1.3373611530420604e-06, ...
#         mtC121100B_idJ   axon     (0.1608744394618834, 1.7119067429183232e-06, 288)
#         mtC240300A_idB   axon     (0.10503985864562787, 1.622890635766261e-06, 1...
#         mtC020200_14_idA axon     (0.21878178643187648, 4.711393244083265e-18, 485)
#
#                                                              section_path_distances  \
# mtype   filename         neurite
# L23_BTC C210401C         axon     (0.43307667421546425, 7.238951991722821e-43, 281)
#         mtC020502A_idA   axon     (0.22781293266058966, 7.582342705925171e-07, 145)
#         mtC031100A_idB   axon     (0.41258925773841915, 3.3306690738754696e-15, ...
#         C200199B-I4      axon     (0.32305297301465663, 1.5543122344752192e-15, ...
#         C190898A-I1      axon     (0.18205011939212187, 4.605649195354999e-12, 453)
#         mtC061100A_idC   axon     (0.39911517388884005, 4.107825191113079e-15, 186)
#         C220797A-I2      axon     (0.2363597187126599, 1.7541523789077473e-13, 286)
#         mtC121100B_idJ   axon      (0.11766629297458894, 0.001131213608353998, 288)
#         mtC240300A_idB   axon     (0.07610638560157791, 0.00016098065015723861, ...
#         mtC020200_14_idA axon     (0.4636630814069061, 1.3396453113289854e-79, 485)
#
#                                                               partition_asymmetry  \
# mtype   filename         neurite
# L23_BTC C210401C         axon      (0.03971466489714665, 0.9830556838212886, 137)
#         mtC020502A_idA   axon       (0.08850837138508372, 0.6165716965549732, 72)
#         mtC031100A_idB   axon      (0.04141085831226676, 0.9704180933762435, 142)
#         C200199B-I4      axon      (0.04463380237053939, 0.9419230494561834, 144)
#         C190898A-I1      axon       (0.04026623638563937, 0.893847962711881, 222)
#         mtC061100A_idC   axon       (0.06865922910699031, 0.7968338068676848, 88)
#         C220797A-I2      axon     (0.029562251279135872, 0.9997174110882383, 138)
#         mtC121100B_idJ   axon     (0.09717648372152363, 0.15341499216645083, 143)
#         mtC240300A_idB   axon     (0.039887140830457156, 0.5332130906947125, 569)
#         mtC020200_14_idA axon     (0.048867693690544556, 0.6735479013661598, 242)
#
#                                                                       segment_radii
# mtype   filename         neurite
# L23_BTC C210401C         axon                       (0.6596349807414149, 0.0, 4800)
#         mtC020502A_idA   axon     (0.21316446664288263, 1.3556530710336007e-171,...
#         mtC031100A_idB   axon           (0.2258047892259594, 6.45620115e-316, 8117)
#         C200199B-I4      axon                       (0.6541809038746695, 0.0, 4287)
#         C190898A-I1      axon                       (0.6513777663654893, 0.0, 4020)
#         mtC061100A_idC   axon                       (0.3861098638317051, 0.0, 7324)
#         C220797A-I2      axon                       (0.6372742973779243, 0.0, 2641)
#         mtC121100B_idJ   axon                     (0.40811031192690206, 0.0, 11115)
#         mtC240300A_idB   axon                      (0.5201825333650251, 0.0, 14716)
#         mtC020200_14_idA axon                       (0.7763378022377799, 0.0, 4646)   @@@@@@@@
#                                                                           section_lengths  \
# mtype   filename         neurite
# L23_BTC C210401C         basal_dendrite    (0.14330143540669857, 0.22719573169336205, 55)
#         mtC020502A_idA   basal_dendrite  (0.20644559506586463, 0.0019216533842354444, 92)
#         mtC031100A_idB   basal_dendrite    (0.18317460317460318, 0.03774931257861136, 63)
#         C200199B-I4      basal_dendrite      (0.0958554512045733, 0.9236638415006094, 31)
#         C190898A-I1      basal_dendrite  (0.23826173826173827, 0.0002101982347594289, 91)
#         mtC061100A_idC   basal_dendrite   (0.2145578231292517, 0.0036057246270233545, 75)
#         C220797A-I2      basal_dendrite  (0.37835479850436227, 7.464144857749488e-10, 83)
#         mtC121100B_idJ   basal_dendrite    (0.16777256022866477, 0.33664122853492295, 31)
#         mtC240300A_idB   basal_dendrite     (0.09209227732543794, 0.5289419883672806, 84)
#         mtC020200_14_idA basal_dendrite     (0.14417212881162725, 0.1995489144648266, 58)
#
#                                                                  section_radial_distances  \
# mtype   filename         neurite
# L23_BTC C210401C         basal_dendrite     (0.09614234449760765, 0.7011390763718283, 55)
#         mtC020502A_idA   basal_dendrite   (0.2346569709891114, 0.0002528037396671845, 92)
#         mtC031100A_idB   basal_dendrite   (0.3458730158730159, 1.380496477354498e-06, 63)
#         C200199B-I4      basal_dendrite    (0.22243772968558595, 0.09113440649122717, 31)
#         C190898A-I1      basal_dendrite  (0.4662837162837163, 2.9821403743546667e-15, 91)
#         mtC061100A_idC   basal_dendrite   (0.3517006802721088, 7.551928937754582e-08, 75)
#         C220797A-I2      basal_dendrite    (0.13815953469048609, 0.11391515957491405, 83)
#         mtC121100B_idJ   basal_dendrite   (0.30634953042057983, 0.005832692648934268, 31)
#         mtC240300A_idB   basal_dendrite   (0.2603010115963484, 7.127919815319572e-05, 84)
#         mtC020200_14_idA basal_dendrite    (0.11607295525790824, 0.43825157283599236, 58)
#
#                                                                     section_path_distances  \
# mtype   filename         neurite
# L23_BTC C210401C         basal_dendrite      (0.09973086124401914, 0.6577285330497541, 55)
#         mtC020502A_idA   basal_dendrite     (0.2266237721769588, 0.000462594646922887, 92)
#         mtC031100A_idB   basal_dendrite   (0.33420634920634923, 3.588179128044544e-06, 63)
#         C200199B-I4      basal_dendrite     (0.21866067782768478, 0.10096927635136266, 31)
#         C190898A-I1      basal_dendrite  (0.45079920079920077, 4.6629367034256575e-15, 91)
#         mtC061100A_idC   basal_dendrite    (0.3096598639455782, 3.702256756499267e-06, 75)
#         C220797A-I2      basal_dendrite      (0.1389073535521396, 0.10815525153389738, 83)
#         mtC121100B_idJ   basal_dendrite    (0.31109636586361783, 0.004857904813425407, 31)
#         mtC240300A_idB   basal_dendrite  (0.27707870713052063, 1.8119218198608955e-05, 84)
#         mtC020200_14_idA basal_dendrite      (0.1578797378170419, 0.12723718918478244, 58)
#
#                                                                     partition_asymmetry  \
# mtype   filename         neurite
# L23_BTC C210401C         basal_dendrite   (0.06661971830985916, 0.9997144455938968, 25)
#         mtC020502A_idA   basal_dendrite  (0.21341143556565834, 0.05797063996712315, 43)
#         mtC031100A_idB   basal_dendrite    (0.04802867383512545, 0.999999169020275, 30)
#         C200199B-I4      basal_dendrite     (0.1152542372881356, 0.984444559060269, 14)
#         C190898A-I1      basal_dendrite   (0.08267581475128645, 0.9356500665026692, 44)
#         mtC061100A_idC   basal_dendrite   (0.10667361835245047, 0.8308034018615347, 35)
#         C220797A-I2      basal_dendrite   (0.2161710037174721, 0.06496245057207839, 40)
#         mtC121100B_idJ   basal_dendrite  (0.25012106537530265, 0.31583419581161265, 14)
#         mtC240300A_idB   basal_dendrite   (0.06866057233704292, 0.9945419343770261, 37)
#         mtC020200_14_idA basal_dendrite  (0.24310480693459416, 0.09059650442608846, 27)
#
#                                                                              segment_radii
# mtype   filename         neurite
# L23_BTC C210401C         basal_dendrite  (0.2975399691118329, 1.5065678415352957e-139, ...
#         mtC020502A_idA   basal_dendrite  (0.3009982753394619, 2.3050852882355974e-212, ...
#         mtC031100A_idB   basal_dendrite  (0.30531355896745693, 2.5147057020483197e-234,...
#         C200199B-I4      basal_dendrite   (0.4092280642582321, 7.595448221859184e-95, 672)
#         C190898A-I1      basal_dendrite  (0.24550069831767546, 1.7979743180656008e-56, ...
#         mtC061100A_idC   basal_dendrite  (0.20894585920967218, 8.521845108233301e-124, ...
#         C220797A-I2      basal_dendrite  (0.31359999565657243, 2.104066142728413e-67, 818)
#         mtC121100B_idJ   basal_dendrite  (0.24703563291655783, 2.1910888126803224e-74, ...
#         mtC240300A_idB   basal_dendrite  (0.3648620341204424, 9.520170096061654e-145, 1...
#         mtC020200_14_idA basal_dendrite                    (0.5760439649815714, 0.0, 1399)   @@@@@@@@
#                                          section_lengths  \
# mtype   filename         neurite
# L23_BTC C210401C         apical_dendrite            None
#         mtC020502A_idA   apical_dendrite            None
#         mtC031100A_idB   apical_dendrite            None
#         C200199B-I4      apical_dendrite            None
#         C190898A-I1      apical_dendrite            None
#         mtC061100A_idC   apical_dendrite            None
#         C220797A-I2      apical_dendrite            None
#         mtC121100B_idJ   apical_dendrite            None
#         mtC240300A_idB   apical_dendrite            None
#         mtC020200_14_idA apical_dendrite            None
#
#                                          section_radial_distances  \
# mtype   filename         neurite
# L23_BTC C210401C         apical_dendrite                     None
#         mtC020502A_idA   apical_dendrite                     None
#         mtC031100A_idB   apical_dendrite                     None
#         C200199B-I4      apical_dendrite                     None
#         C190898A-I1      apical_dendrite                     None
#         mtC061100A_idC   apical_dendrite                     None
#         C220797A-I2      apical_dendrite                     None
#         mtC121100B_idJ   apical_dendrite                     None
#         mtC240300A_idB   apical_dendrite                     None
#         mtC020200_14_idA apical_dendrite                     None
#
#                                          section_path_distances  \
# mtype   filename         neurite
# L23_BTC C210401C         apical_dendrite                   None
#         mtC020502A_idA   apical_dendrite                   None
#         mtC031100A_idB   apical_dendrite                   None
#         C200199B-I4      apical_dendrite                   None
#         C190898A-I1      apical_dendrite                   None
#         mtC061100A_idC   apical_dendrite                   None
#         C220797A-I2      apical_dendrite                   None
#         mtC121100B_idJ   apical_dendrite                   None
#         mtC240300A_idB   apical_dendrite                   None
#         mtC020200_14_idA apical_dendrite                   None
#
#                                          partition_asymmetry segment_radii
# mtype   filename         neurite
# L23_BTC C210401C         apical_dendrite                None          None
#         mtC020502A_idA   apical_dendrite                None          None
#         mtC031100A_idB   apical_dendrite                None          None
#         C200199B-I4      apical_dendrite                None          None
#         C190898A-I1      apical_dendrite                None          None
#         mtC061100A_idC   apical_dendrite                None          None
#         C220797A-I2      apical_dendrite                None          None
#         mtC121100B_idJ   apical_dendrite                None          None
#         mtC240300A_idB   apical_dendrite                None          None
#         mtC020200_14_idA apical_dendrite                None          None   @@@@@@@@
#                                    section_lengths section_radial_distances  \
# mtype   filename         neurite
# L23_BTC C210401C         undefined            None                     None
#         mtC020502A_idA   undefined            None                     None
#         mtC031100A_idB   undefined            None                     None
#         C200199B-I4      undefined            None                     None
#         C190898A-I1      undefined            None                     None
#         mtC061100A_idC   undefined            None                     None
#         C220797A-I2      undefined            None                     None
#         mtC121100B_idJ   undefined            None                     None
#         mtC240300A_idB   undefined            None                     None
#         mtC020200_14_idA undefined            None                     None
#
#                                    section_path_distances partition_asymmetry  \
# mtype   filename         neurite
# L23_BTC C210401C         undefined                   None                None
#         mtC020502A_idA   undefined                   None                None
#         mtC031100A_idB   undefined                   None                None
#         C200199B-I4      undefined                   None                None
#         C190898A-I1      undefined                   None                None
#         mtC061100A_idC   undefined                   None                None
#         C220797A-I2      undefined                   None                None
#         mtC121100B_idJ   undefined                   None                None
#         mtC240300A_idB   undefined                   None                None
#         mtC020200_14_idA undefined                   None                None
#
#                                    segment_radii
# mtype   filename         neurite
# L23_BTC C210401C         undefined          None
#         mtC020502A_idA   undefined          None
#         mtC031100A_idB   undefined          None
#         C200199B-I4      undefined          None
#         C190898A-I1      undefined          None
#         mtC061100A_idC   undefined          None
#         C220797A-I2      undefined          None
#         mtC121100B_idJ   undefined          None
#         mtC240300A_idB   undefined          None
#         mtC020200_14_idA undefined          None   @@@@@@@@
#                                                                     section_lengths  \
# mtype   filename         neurite
# L23_BTC C210401C         all       (0.16408677982309347, 8.72379664063061e-08, 336)
#         mtC020502A_idA   all      (0.16520534392816955, 7.961518527221934e-06, 237)
#         mtC031100A_idB   all      (0.13667520234744857, 9.443846939793943e-06, 352)
#         C200199B-I4      all      (0.14165693626177822, 1.0631476295763775e-05, ...
#         C190898A-I1      all      (0.11137948575656678, 1.255357047891259e-05, 544)
#         mtC061100A_idC   all      (0.2277677898173193, 1.0852319043408443e-11, 261)
#         C220797A-I2      all        (0.06924217193979168, 0.07374026498716246, 369)
#         mtC121100B_idJ   all         (0.06575682937751903, 0.1468892632546155, 319)
#         mtC240300A_idB   all      (0.059607845456687236, 0.0033871005908172156, ...
#         mtC020200_14_idA all      (0.20466120850332195, 8.307119967966382e-18, 543)
#
#                                                            section_radial_distances  \
# mtype   filename         neurite
# L23_BTC C210401C         all       (0.3912505834272509, 8.868122823613675e-42, 336)
#         mtC020502A_idA   all       (0.11572828659662565, 0.004450962857415752, 237)
#         mtC031100A_idB   all       (0.08620355826079368, 0.015044870440794833, 352)
#         C200199B-I4      all      (0.15594028269231053, 8.101053559084193e-07, 322)
#         C190898A-I1      all        (0.255889752127266, 1.218116048190033e-27, 544)
#         mtC061100A_idC   all      (0.2254129706713889, 1.8583468097688183e-11, 261)
#         C220797A-I2      all       (0.1370947203447938, 5.105865830357104e-06, 369)
#         mtC121100B_idJ   all      (0.15640020898641588, 8.445286905356397e-07, 319)
#         mtC240300A_idB   all      (0.11244476054441484, 2.7517117077511697e-10, ...
#         mtC020200_14_idA all      (0.18255573959410237, 2.961043476327274e-14, 543)
#
#                                                              section_path_distances  \
# mtype   filename         neurite
# L23_BTC C210401C         all      (0.3612524617784001, 1.1118045252623614e-35, 336)
#         mtC020502A_idA   all        (0.06576346476369534, 0.27313773840083166, 237)
#         mtC031100A_idB   all      (0.32549714204681807, 2.6990940011857654e-30, ...
#         C200199B-I4      all      (0.31077211317755804, 1.6364596756448217e-25, ...
#         C190898A-I1      all      (0.17519561598224195, 3.4982943468380207e-13, ...
#         mtC061100A_idC   all      (0.22861541673190333, 8.919531779838508e-12, 261)
#         C220797A-I2      all      (0.20642309073693146, 3.8480330033507926e-13, ...
#         mtC121100B_idJ   all        (0.08941185251530079, 0.01633506240056226, 319)
#         mtC240300A_idB   all       (0.06996200885802807, 0.00030441782938361, 1236)
#         mtC020200_14_idA all      (0.38346052373170886, 1.917855119862877e-61, 543)
#
#                                                               partition_asymmetry  \
# mtype   filename         neurite
# L23_BTC C210401C         all         (0.03613104298035805, 0.98532788597909, 162)
#         mtC020502A_idA   all      (0.12736572890025574, 0.05299688855270601, 115)
#         mtC031100A_idB   all       (0.03903409480688756, 0.9606698443839784, 172)
#         C200199B-I4      all      (0.038895619066455694, 0.9727485686584825, 158)
#         C190898A-I1      all       (0.03349740330206961, 0.9465419761060224, 266)
#         mtC061100A_idC   all      (0.08307280384373696, 0.37746468766690855, 123)
#         C220797A-I2      all        (0.04443410234248609, 0.887450468333839, 178)
#         mtC121100B_idJ   all       (0.07898524369507574, 0.3054935572310672, 157)
#         mtC240300A_idB   all       (0.03177186468646865, 0.7513382601830345, 606)
#         mtC020200_14_idA all      (0.059592786146514844, 0.3557766973897909, 269)
#
#                                                                       segment_radii
# mtype   filename         neurite
# L23_BTC C210401C         all                        (0.5424616394104583, 0.0, 6815)
#         mtC020502A_idA   all      (0.16870676305329735, 1.8610243196487768e-177,...
#         mtC031100A_idB   all      (0.17808440031707218, 1.5397016857876226e-277,...
#         C200199B-I4      all                        (0.5300478398106135, 0.0, 4959)
#         C190898A-I1      all                        (0.5313384503195027, 0.0, 5156)
#         mtC061100A_idC   all      (0.17760954039930324, 4.514072061272808e-272, ...
#         C220797A-I2      all                         (0.520422739818895, 0.0, 3459)
#         mtC121100B_idJ   all                      (0.43438359913980823, 0.0, 12626)
#         mtC240300A_idB   all                       (0.4913846843894977, 0.0, 16055)
#         mtC020200_14_idA all                        (0.6009927108832274, 0.0, 6045)   @@@@@@@@
#                                  section_lengths section_radial_distances  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA soma               None                     None
#       C040426            soma               None                     None
#       vd101020A_idA      soma               None                     None
#       C180298B-I3        soma               None                     None
#       C050896A-I         soma               None                     None
#       C290500C-I4        soma               None                     None
#       mtC210301C_idB     soma               None                     None
#       rp101213_L5-2_idB  soma               None                     None
#       mtC171001A_idC     soma               None                     None
#       C040601            soma               None                     None
#
#                                  section_path_distances partition_asymmetry  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA soma                      None                None
#       C040426            soma                      None                None
#       vd101020A_idA      soma                      None                None
#       C180298B-I3        soma                      None                None
#       C050896A-I         soma                      None                None
#       C290500C-I4        soma                      None                None
#       mtC210301C_idB     soma                      None                None
#       rp101213_L5-2_idB  soma                      None                None
#       mtC171001A_idC     soma                      None                None
#       C040601            soma                      None                None
#
#                                  segment_radii
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA soma             None
#       C040426            soma             None
#       vd101020A_idA      soma             None
#       C180298B-I3        soma             None
#       C050896A-I         soma             None
#       C290500C-I4        soma             None
#       mtC210301C_idB     soma             None
#       rp101213_L5-2_idB  soma             None
#       mtC171001A_idC     soma             None
#       C040601            soma             None   @@@@@@@@
#                                                                     section_lengths  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA axon     (0.22309639477764057, 5.304645611658998e-13, 309)
#       C040426            axon     (0.15764553567300135, 1.9328486697833824e-05, ...
#       vd101020A_idA      axon     (0.21294675970934965, 3.4525186938670926e-35, ...
#       C180298B-I3        axon        (0.06033312599350335, 0.2974952215392722, 273)
#       C050896A-I         axon      (0.09087444110532875, 0.009260792587241107, 350)
#       C290500C-I4        axon     (0.14079037637586672, 3.490583735266117e-05, 293)
#       mtC210301C_idB     axon       (0.03983597112917953, 0.21464536821896396, 872)
#       rp101213_L5-2_idB  axon     (0.11463951224790137, 0.0016022574485203833, 287)
#       mtC171001A_idC     axon     (0.24942374856628644, 5.599043451098851e-11, 201)
#       C040601            axon       (0.09215044295286436, 0.11905801626778423, 169)
#
#                                                            section_radial_distances  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA axon     (0.1638260166569308, 3.4529514858494537e-07, 309)
#       C040426            axon     (0.22023396680075832, 3.092690548101018e-10, 243)
#       vd101020A_idA      axon     (0.2514552922226783, 6.7379964845059936e-49, 1...
#       C180298B-I3        axon     (0.21765982445227727, 4.211353488159375e-11, 273)
#       C050896A-I         axon     (0.32837792274426447, 1.660943195289337e-30, 350)
#       C290500C-I4        axon     (0.1680207798483796, 3.3650878306090704e-07, 293)
#       mtC210301C_idB     axon     (0.3957481847036828, 1.0670659869583315e-94, 872)
#       rp101213_L5-2_idB  axon      (0.3511044530865837, 3.774758283725532e-15, 287)
#       mtC171001A_idC     axon      (0.3801120417187598, 5.551115123125783e-16, 201)
#       C040601            axon     (0.2243153342781834, 1.1800227606162395e-07, 169)
#
#                                                              section_path_distances  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA axon        (0.07205761651594585, 0.0968450662092929, 309)
#       C040426            axon       (0.265353493318537, 8.881784197001252e-15, 243)
#       vd101020A_idA      axon     (0.1467198613481587, 6.287193302243262e-17, 1251)
#       C180298B-I3        axon     (0.13400511438247287, 0.00018353909778889843, ...
#       C050896A-I         axon     (0.15881550978523784, 1.5247690021702454e-07, ...
#       C290500C-I4        axon          (0.05741554950531362, 0.31696819114315, 293)
#       mtC210301C_idB     axon      (0.2863303839297361, 8.942006564843027e-50, 872)
#       rp101213_L5-2_idB  axon      (0.3889270562197453, 3.774758283725532e-15, 287)
#       mtC171001A_idC     axon      (0.3351367698202833, 5.551115123125783e-16, 201)
#       C040601            axon       (0.09987800119242592, 0.07306626490330426, 169)
#
#                                                                partition_asymmetry  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA axon        (0.0619562395574697, 0.6193569578933414, 154)
#       C040426            axon       (0.09644468707616456, 0.2349665674191187, 118)
#       vd101020A_idA      axon      (0.04978414055883009, 0.21801874795006493, 623)
#       C180298B-I3        axon      (0.08580049592208645, 0.28842184577788466, 136)
#       C050896A-I         axon       (0.10850491377822223, 0.0429745879406892, 174)
#       C290500C-I4        axon      (0.09060046011733691, 0.20126997341550346, 146)
#       mtC210301C_idB     axon      (0.0977932031097028, 0.002526273004566093, 434)
#       rp101213_L5-2_idB  axon     (0.1928387616461011, 8.116028632842998e-05, 143)
#       mtC171001A_idC     axon        (0.08349925335988054, 0.5171071049714462, 96)
#       C040601            axon      (0.18644781144781145, 0.007624271711532016, 81)
#
#                                                       segment_radii
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA axon      (0.9580629090983561, 0.0, 21907)
#       C040426            axon       (0.5268029571670376, 0.0, 6779)
#       vd101020A_idA      axon      (0.2834074961297031, 0.0, 36704)
#       C180298B-I3        axon       (0.8976693934249113, 0.0, 3705)
#       C050896A-I         axon       (0.5745247498877716, 0.0, 2866)
#       C290500C-I4        axon       (0.9024379113005541, 0.0, 4287)
#       mtC210301C_idB     axon     (0.19952523377491743, 0.0, 12542)
#       rp101213_L5-2_idB  axon     (0.20296582542776165, 0.0, 10005)
#       mtC171001A_idC     axon      (0.2219159821926261, 0.0, 11915)
#       C040601            axon       (0.8209917803269804, 0.0, 3138)   @@@@@@@@
#                                                                            section_lengths  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA basal_dendrite  (0.25184438094170825, 0.00016069040571720095, 81)
#       C040426            basal_dendrite    (0.28624825662482567, 0.030199883064195188, 25)
#       vd101020A_idA      basal_dendrite  (0.20140940163726898, 5.056098573630319e-05, 164)
#       C180298B-I3        basal_dendrite     (0.14990224828934506, 0.15040577654801002, 60)
#       C050896A-I         basal_dendrite   (0.2509238728750924, 0.00015545056528865064, 82)
#       C290500C-I4        basal_dendrite     (0.13950056965689844, 0.10856911184252771, 81)
#       mtC210301C_idB     basal_dendrite   (0.14288368636194723, 0.015519720557198635, 144)
#       rp101213_L5-2_idB  basal_dendrite      (0.296901229526791, 0.008101225540795953, 31)
#       mtC171001A_idC     basal_dendrite     (0.22853185595567868, 0.22353723474580856, 20)
#       C040601            basal_dendrite      (0.13345176571920758, 0.3052042085268992, 54)
#
#                                                                   section_radial_distances  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA basal_dendrite  (0.24336489792869015, 0.00030034152251023905, 81)
#       C040426            basal_dendrite      (0.3054393305439331, 0.01684886711821587, 25)
#       vd101020A_idA      basal_dendrite    (0.3318845472191746, 5.35238520171788e-13, 164)
#       C180298B-I3        basal_dendrite  (0.37947214076246333, 1.2312353847576674e-07, 60)
#       C050896A-I         basal_dendrite   (0.22516629711751662, 0.0009842167203004681, 82)
#       C290500C-I4        basal_dendrite    (0.2229319586858669, 0.0012360123390723343, 81)
#       mtC210301C_idB     basal_dendrite  (0.18248327759197325, 0.0007383582967719349, 144)
#       rp101213_L5-2_idB  basal_dendrite       (0.254797876684361, 0.03446409447342125, 31)
#       mtC171001A_idC     basal_dendrite    (0.5415512465373962, 7.198016269249763e-06, 20)
#       C040601            basal_dendrite       (0.13280577088716625, 0.310423802375948, 54)
#
#                                                                     section_path_distances  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA basal_dendrite   (0.22194206309183617, 0.0013228653325966233, 81)
#       C040426            basal_dendrite     (0.3319386331938633, 0.007082026667483032, 25)
#       vd101020A_idA      basal_dendrite  (0.36583255970968015, 3.1086244689504383e-15, ...
#       C180298B-I3        basal_dendrite   (0.38641251221896383, 6.561868459709075e-08, 60)
#       C050896A-I         basal_dendrite    (0.17804878048780487, 0.016938467821429604, 82)
#       C290500C-I4        basal_dendrite   (0.2516762854634766, 0.00016211961898515703, 81)
#       mtC210301C_idB     basal_dendrite  (0.20742753623188406, 7.363747655964037e-05, 144)
#       rp101213_L5-2_idB  basal_dendrite      (0.2139195136336827, 0.11298953074744633, 31)
#       mtC171001A_idC     basal_dendrite     (0.590027700831025, 5.632861980187087e-07, 20)
#       C040601            basal_dendrite     (0.14184969853574506, 0.24082694158236118, 54)
#
#                                                                     partition_asymmetry  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA basal_dendrite   (0.05673274094326726, 0.9995828266599446, 38)
#       C040426            basal_dendrite   (0.12455902306648575, 0.9888508602948595, 11)
#       vd101020A_idA      basal_dendrite   (0.1512218045112782, 0.10630894336803298, 80)
#       C180298B-I3        basal_dendrite    (0.1762019230769231, 0.3959911045915403, 26)
#       C050896A-I         basal_dendrite    (0.1202706088699574, 0.6504174353723109, 39)
#       C290500C-I4        basal_dendrite  (0.18215985968428966, 0.17589274455485604, 39)
#       mtC210301C_idB     basal_dendrite   (0.10173160173160173, 0.5963054382556534, 66)
#       rp101213_L5-2_idB  basal_dendrite    (0.1897590361445783, 0.6501465217107327, 14)
#       mtC171001A_idC     basal_dendrite     (0.16494082840236687, 0.960593311337042, 8)
#       C040601            basal_dendrite   (0.06866043613707165, 0.9994892414840678, 25)
#
#                                                                              segment_radii
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA basal_dendrite  (0.22513219023395442, 6.096594314864545e-188, ...
#       C040426            basal_dendrite  (0.4290021003607142, 5.449009437098041e-112, 724)
#       vd101020A_idA      basal_dendrite  (0.08817698929276052, 3.921819482013959e-24, 4...
#       C180298B-I3        basal_dendrite  (0.24807910145008866, 1.2995114123805774e-48, ...
#       C050896A-I         basal_dendrite  (0.15925174785391066, 1.0823535317705107e-14, ...
#       C290500C-I4        basal_dendrite  (0.29356393742950043, 6.5350690167314915e-106,...
#       mtC210301C_idB     basal_dendrite  (0.4379931525358269, 1.899339259142615e-263, 1...
#       rp101213_L5-2_idB  basal_dendrite  (0.2599591941523214, 5.2094943043395536e-92, 1...
#       mtC171001A_idC     basal_dendrite   (0.07190677381946753, 0.003495817537763563, 634)
#       C040601            basal_dendrite  (0.16517860240495705, 4.4689617858443914e-33, ...   @@@@@@@@
#                                          section_lengths  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA apical_dendrite            None
#       C040426            apical_dendrite            None
#       vd101020A_idA      apical_dendrite            None
#       C180298B-I3        apical_dendrite            None
#       C050896A-I         apical_dendrite            None
#       C290500C-I4        apical_dendrite            None
#       mtC210301C_idB     apical_dendrite            None
#       rp101213_L5-2_idB  apical_dendrite            None
#       mtC171001A_idC     apical_dendrite            None
#       C040601            apical_dendrite            None
#
#                                          section_radial_distances  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA apical_dendrite                     None
#       C040426            apical_dendrite                     None
#       vd101020A_idA      apical_dendrite                     None
#       C180298B-I3        apical_dendrite                     None
#       C050896A-I         apical_dendrite                     None
#       C290500C-I4        apical_dendrite                     None
#       mtC210301C_idB     apical_dendrite                     None
#       rp101213_L5-2_idB  apical_dendrite                     None
#       mtC171001A_idC     apical_dendrite                     None
#       C040601            apical_dendrite                     None
#
#                                          section_path_distances  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA apical_dendrite                   None
#       C040426            apical_dendrite                   None
#       vd101020A_idA      apical_dendrite                   None
#       C180298B-I3        apical_dendrite                   None
#       C050896A-I         apical_dendrite                   None
#       C290500C-I4        apical_dendrite                   None
#       mtC210301C_idB     apical_dendrite                   None
#       rp101213_L5-2_idB  apical_dendrite                   None
#       mtC171001A_idC     apical_dendrite                   None
#       C040601            apical_dendrite                   None
#
#                                          partition_asymmetry segment_radii
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA apical_dendrite                None          None
#       C040426            apical_dendrite                None          None
#       vd101020A_idA      apical_dendrite                None          None
#       C180298B-I3        apical_dendrite                None          None
#       C050896A-I         apical_dendrite                None          None
#       C290500C-I4        apical_dendrite                None          None
#       mtC210301C_idB     apical_dendrite                None          None
#       rp101213_L5-2_idB  apical_dendrite                None          None
#       mtC171001A_idC     apical_dendrite                None          None
#       C040601            apical_dendrite                None          None   @@@@@@@@
#                                    section_lengths section_radial_distances  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA undefined            None                     None
#       C040426            undefined            None                     None
#       vd101020A_idA      undefined            None                     None
#       C180298B-I3        undefined            None                     None
#       C050896A-I         undefined            None                     None
#       C290500C-I4        undefined            None                     None
#       mtC210301C_idB     undefined            None                     None
#       rp101213_L5-2_idB  undefined            None                     None
#       mtC171001A_idC     undefined            None                     None
#       C040601            undefined            None                     None
#
#                                    section_path_distances partition_asymmetry  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA undefined                   None                None
#       C040426            undefined                   None                None
#       vd101020A_idA      undefined                   None                None
#       C180298B-I3        undefined                   None                None
#       C050896A-I         undefined                   None                None
#       C290500C-I4        undefined                   None                None
#       mtC210301C_idB     undefined                   None                None
#       rp101213_L5-2_idB  undefined                   None                None
#       mtC171001A_idC     undefined                   None                None
#       C040601            undefined                   None                None
#
#                                    segment_radii
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA undefined          None
#       C040426            undefined          None
#       vd101020A_idA      undefined          None
#       C180298B-I3        undefined          None
#       C050896A-I         undefined          None
#       C290500C-I4        undefined          None
#       mtC210301C_idB     undefined          None
#       rp101213_L5-2_idB  undefined          None
#       mtC171001A_idC     undefined          None
#       C040601            undefined          None   @@@@@@@@
#                                                                     section_lengths  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA all       (0.2288907469342252, 8.723221307198819e-17, 390)
#       C040426            all      (0.15750188068551776, 5.812690992645919e-06, 268)
#       vd101020A_idA      all      (0.18623242481899727, 5.7794585617794726e-31, ...
#       C180298B-I3        all         (0.05076990239111777, 0.3859481743462344, 333)
#       C050896A-I         all       (0.09626643427104155, 0.001231095287491546, 432)
#       C290500C-I4        all      (0.10333042938303413, 0.0011360531590953737, 374)
#       mtC210301C_idB     all       (0.04429034789121415, 0.08362764293171984, 1016)
#       rp101213_L5-2_idB  all       (0.10355550529852675, 0.003103263290726299, 318)
#       mtC171001A_idC     all      (0.20893041314143285, 1.451391129503321e-08, 221)
#       C040601            all        (0.06195339596497219, 0.37106252320118915, 223)
#
#                                                            section_radial_distances  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA all      (0.1694035674470457, 1.7324439660626467e-09, 390)
#       C040426            all      (0.17350983329856437, 3.795183898258614e-07, 268)
#       vd101020A_idA      all      (0.20900738837134597, 6.850062187625286e-39, 1...
#       C180298B-I3        all       (0.1864022063721441, 6.326738022366385e-10, 333)
#       C050896A-I         all      (0.25549197178749616, 8.470726431025005e-23, 432)
#       C290500C-I4        all      (0.14721637827968748, 5.215400660230074e-07, 374)
#       mtC210301C_idB     all      (0.3408003400053101, 4.717820384494526e-82, 1016)
#       rp101213_L5-2_idB  all      (0.28820297019040236, 6.617840135911007e-22, 318)
#       mtC171001A_idC     all      (0.31671551469758025, 1.6653345369377348e-15, ...
#       C040601            all        (0.1537363093239113, 7.30018877589389e-05, 223)
#
#                                                              section_path_distances  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA all       (0.09028428093645485, 0.005307870709221896, 390)
#       C040426            all      (0.21542225340894006, 8.296330289425669e-11, 268)
#       vd101020A_idA      all      (0.15080876720452693, 1.882736394026983e-20, 1...
#       C180298B-I3        all      (0.11709906169858929, 0.00035922868249638196, ...
#       C050896A-I         all      (0.11794179545934702, 3.057583643240047e-05, 432)
#       C290500C-I4        all        (0.08179524370012697, 0.01834985319709015, 374)
#       mtC210301C_idB     all      (0.24717553863894845, 2.3045450242937355e-43, ...
#       rp101213_L5-2_idB  all      (0.32154357284397345, 3.6590715596628014e-27, ...
#       mtC171001A_idC     all       (0.2770181479369495, 9.880984919163893e-15, 221)
#       C040601            all      (0.1600813138909976, 3.0860858523218404e-05, 223)
#
#                                                                 partition_asymmetry  \
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA all        (0.07093155157149181, 0.31920297779215834, 192)
#       C040426            all         (0.09000861326442722, 0.2611506607320645, 129)
#       vd101020A_idA      all         (0.04013853670604243, 0.3822457458867349, 703)
#       C180298B-I3        all         (0.07958351536333187, 0.2774865568402304, 162)
#       C050896A-I         all         (0.06932119976337021, 0.2926484524674343, 213)
#       C290500C-I4        all        (0.07839984733188617, 0.23049332124358413, 185)
#       mtC210301C_idB     all       (0.07290005125576628, 0.027420215543363602, 500)
#       rp101213_L5-2_idB  all      (0.1782606522692818, 0.00014752213760937938, 157)
#       mtC171001A_idC     all           (0.0706507489102291, 0.674981519236687, 104)
#       C040601            all         (0.1312869614193185, 0.05504938023230632, 106)
#
#                                                                       segment_radii
# mtype filename           neurite
# L5_MC rp101020_2_INT_idA all                       (0.7508811942330066, 0.0, 28038)
#       C040426            all                       (0.43118158379341004, 0.0, 7503)
#       vd101020A_idA      all                      (0.24953247039721627, 0.0, 41238)
#       C180298B-I3        all                         (0.772611597991971, 0.0, 4651)
#       C050896A-I         all                        (0.5075309058560079, 0.0, 3536)
#       C290500C-I4        all                        (0.7796128629409929, 0.0, 5812)
#       mtC210301C_idB     all            (0.16918973516455732, 2.095886e-317, 14269)
#       rp101213_L5-2_idB  all      (0.1724068260048028, 2.542103238269377e-276, 1...
#       mtC171001A_idC     all                      (0.22985551121696812, 0.0, 12549)
#       C040601            all                        (0.7050639568156156, 0.0, 4626)   @@@@@@@@
#                                          section_lengths  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 soma               None
#        rat_20160914_E1_LH4_cell1 soma               None
#        rat_P16_S1_RH3_20140129   soma               None
#        rat_20170523_E1_LH2_cell1 soma               None
#
#                                          section_radial_distances  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 soma                        None
#        rat_20160914_E1_LH4_cell1 soma                        None
#        rat_P16_S1_RH3_20140129   soma                        None
#        rat_20170523_E1_LH2_cell1 soma                        None
#
#                                          section_path_distances  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 soma                      None
#        rat_20160914_E1_LH4_cell1 soma                      None
#        rat_P16_S1_RH3_20140129   soma                      None
#        rat_20170523_E1_LH2_cell1 soma                      None
#
#                                          partition_asymmetry segment_radii
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 soma                   None          None
#        rat_20160914_E1_LH4_cell1 soma                   None          None
#        rat_P16_S1_RH3_20140129   soma                   None          None
#        rat_20170523_E1_LH2_cell1 soma                   None          None   @@@@@@@@
#                                                                             section_lengths  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 axon     (0.15992950736915323, 7.801456147760177e-10, 647)
#        rat_20160914_E1_LH4_cell1 axon     (0.16728395742839244, 2.550770705767036e-11, 749)
#        rat_P16_S1_RH3_20140129   axon                        (0.4873684177965027, 0.0, 197)
#        rat_20170523_E1_LH2_cell1 axon       (0.2559411711954085, 9.89319737243477e-13, 245)
#
#                                                                    section_radial_distances  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 axon     (0.16482843375807998, 2.0210033646606007e-10, ...
#        rat_20160914_E1_LH4_cell1 axon     (0.10137299687002321, 0.00019829845592023165, ...
#        rat_P16_S1_RH3_20140129   axon                       (0.39869832991521204, 0.0, 197)
#        rat_20170523_E1_LH2_cell1 axon        (0.1038676864342724, 0.01877043125658573, 245)
#
#                                                                      section_path_distances  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 axon      (0.07867610894174105, 0.010395317307175134, 647)
#        rat_20160914_E1_LH4_cell1 axon     (0.13202053304007424, 3.2900996882467837e-07, ...
#        rat_P16_S1_RH3_20140129   axon                        (0.4289355568135067, 0.0, 197)
#        rat_20170523_E1_LH2_cell1 axon       (0.1189335998052705, 0.004432607154251644, 245)
#
#                                                                         partition_asymmetry  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 axon     (0.20037318489330874, 7.735657669982743e-08, 323)
#        rat_20160914_E1_LH4_cell1 axon      (0.11621906422036418, 0.004533794628958643, 374)
#        rat_P16_S1_RH3_20140129   axon       (0.3627245770102913, 8.445677490698245e-11, 98)
#        rat_20170523_E1_LH2_cell1 axon      (0.3323538509124652, 6.831069043755633e-11, 122)
#
#                                                                               segment_radii
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 axon     (0.0350683710811035, 1.2551304112362724e-10, 1...
#        rat_20160914_E1_LH4_cell1 axon     (0.03092018622697923, 1.1549465803708933e-08, ...
#        rat_P16_S1_RH3_20140129   axon     (0.01747837633599697, 0.0006982613832419132, 1...
#        rat_20170523_E1_LH2_cell1 axon     (0.043004741005777, 5.823997517169108e-20, 16889)   @@@@@@@@
#                                                                                  section_lengths  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 basal_dendrite                (0.09375, 0.8534002601324762, 45)
#        rat_20160914_E1_LH4_cell1 basal_dendrite      (0.1307537843682422, 0.413110426157394, 52)
#        rat_P16_S1_RH3_20140129   basal_dendrite  (0.11896050286143166, 0.24344874330342492, 114)
#        rat_20170523_E1_LH2_cell1 basal_dendrite    (0.09636650868878358, 0.5597696267161392, 90)
#
#                                                                          section_radial_distances  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 basal_dendrite     (0.17430555555555555, 0.1710365688761608, 45)
#        rat_20160914_E1_LH4_cell1 basal_dendrite    (0.20960766141489032, 0.03830420557982228, 52)
#        rat_P16_S1_RH3_20140129   basal_dendrite  (0.17309316070925979, 0.024588926566022518, 114)
#        rat_20170523_E1_LH2_cell1 basal_dendrite    (0.18304370721432334, 0.02484402781049544, 90)
#
#                                                                           section_path_distances  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 basal_dendrite   (0.18211805555555555, 0.13720772689859062, 45)
#        rat_20160914_E1_LH4_cell1 basal_dendrite    (0.15083410565338276, 0.2514897726172236, 52)
#        rat_P16_S1_RH3_20140129   basal_dendrite  (0.1818650905338212, 0.015650527190435692, 114)
#        rat_20170523_E1_LH2_cell1 basal_dendrite     (0.1291205897840969, 0.2193805393354571, 90)
#
#                                                                             partition_asymmetry  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 basal_dendrite   (0.10862068965517241, 0.9726291379428124, 20)
#        rat_20160914_E1_LH4_cell1 basal_dendrite  (0.23511904761904762, 0.19288846868711285, 24)
#        rat_P16_S1_RH3_20140129   basal_dendrite   (0.05860805860805861, 0.9994279730958446, 52)
#        rat_20170523_E1_LH2_cell1 basal_dendrite    (0.16666666666666666, 0.369727037212353, 40)
#
#                                                                                      segment_radii
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 basal_dendrite  (0.19671030122230487, 1.500933727256382e-63, 2...
#        rat_20160914_E1_LH4_cell1 basal_dendrite  (0.11140198676401397, 3.0926409639971276e-28, ...
#        rat_P16_S1_RH3_20140129   basal_dendrite                   (0.44673057654126924, 0.0, 6897)
#        rat_20170523_E1_LH2_cell1 basal_dendrite                    (0.4892864943464956, 0.0, 5809)   @@@@@@@@
#                                                                                    section_lengths  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 apical_dendrite  (0.19269440400826027, 0.005204817452209687, 109)
#        rat_20160914_E1_LH4_cell1 apical_dendrite     (0.09907901930274612, 0.5322517867014103, 79)
#        rat_P16_S1_RH3_20140129   apical_dendrite    (0.13199205724776142, 0.15540031988351755, 93)
#        rat_20170523_E1_LH2_cell1 apical_dendrite    (0.15895610913404506, 0.04322940735041114, 99)
#
#                                                                            section_radial_distances  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 apical_dendrite  (0.2914790615796066, 2.4374251608172415e-06, 109)
#        rat_20160914_E1_LH4_cell1 apical_dendrite   (0.24315572564027083, 0.0009515756212866711, 79)
#        rat_P16_S1_RH3_20140129   apical_dendrite    (0.16720992094713574, 0.034182781567793086, 93)
#        rat_20170523_E1_LH2_cell1 apical_dendrite     (0.17071066537258708, 0.02419461006903345, 99)
#
#                                                                            section_path_distances  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 apical_dendrite  (0.17119740004739498, 0.01803602556448347, 109)
#        rat_20160914_E1_LH4_cell1 apical_dendrite  (0.22448378821649353, 0.002936883515655686, 79)
#        rat_P16_S1_RH3_20140129   apical_dendrite   (0.14510509160391144, 0.09223855426266903, 93)
#        rat_20170523_E1_LH2_cell1 apical_dendrite    (0.08044861425644344, 0.6930934989347561, 99)
#
#                                                                             partition_asymmetry  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 apical_dendrite  (0.07683803206191266, 0.9595647241111478, 54)
#        rat_20160914_E1_LH4_cell1 apical_dendrite   (0.1643434864911375, 0.3313906388744503, 39)
#        rat_P16_S1_RH3_20140129   apical_dendrite  (0.16289038579301898, 0.2785576415593103, 46)
#        rat_20170523_E1_LH2_cell1 apical_dendrite  (0.11921891058581706, 0.6295642596457991, 49)
#
#                                                                                       segment_radii
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 apical_dendrite  (0.2495579057984736, 3.008452807776769e-216, 5...
#        rat_20160914_E1_LH4_cell1 apical_dendrite  (0.09035847582719381, 1.1137693881426169e-26, ...
#        rat_P16_S1_RH3_20140129   apical_dendrite                    (0.3965871785701476, 0.0, 6149)
#        rat_20170523_E1_LH2_cell1 apical_dendrite                    (0.4764837485413065, 0.0, 8633)   @@@@@@@@
#                                            section_lengths  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 undefined            None
#        rat_20160914_E1_LH4_cell1 undefined            None
#        rat_P16_S1_RH3_20140129   undefined            None
#        rat_20170523_E1_LH2_cell1 undefined            None
#
#                                            section_radial_distances  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 undefined                     None
#        rat_20160914_E1_LH4_cell1 undefined                     None
#        rat_P16_S1_RH3_20140129   undefined                     None
#        rat_20170523_E1_LH2_cell1 undefined                     None
#
#                                            section_path_distances  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 undefined                   None
#        rat_20160914_E1_LH4_cell1 undefined                   None
#        rat_P16_S1_RH3_20140129   undefined                   None
#        rat_20170523_E1_LH2_cell1 undefined                   None
#
#                                            partition_asymmetry segment_radii
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 undefined                None          None
#        rat_20160914_E1_LH4_cell1 undefined                None          None
#        rat_P16_S1_RH3_20140129   undefined                None          None
#        rat_20170523_E1_LH2_cell1 undefined                None          None   @@@@@@@@
#                                                                             section_lengths  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 all       (0.1743142666544584, 6.328271240363392e-15, 801)
#        rat_20160914_E1_LH4_cell1 all      (0.2078706528370958, 3.4416913763379853e-15, 880)
#        rat_P16_S1_RH3_20140129   all      (0.38910188891229547, 3.1086244689504383e-15, ...
#        rat_20170523_E1_LH2_cell1 all      (0.22594127463006553, 3.9968028886505635e-15, ...
#
#                                                                    section_radial_distances  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 all      (0.09854096814372024, 4.483556341894346e-05, 801)
#        rat_20160914_E1_LH4_cell1 all       (0.12249847467968274, 5.98481023628139e-08, 880)
#        rat_P16_S1_RH3_20140129   all      (0.22134915619221496, 7.216449660063518e-15, 404)
#        rat_20170523_E1_LH2_cell1 all      (0.09714219407883831, 0.0020929689331080636, 434)
#
#                                                                      section_path_distances  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 all        (0.053562993871165115, 0.0831736435381536, 801)
#        rat_20160914_E1_LH4_cell1 all      (0.12256711409395973, 5.869747710107731e-08, 880)
#        rat_P16_S1_RH3_20140129   all      (0.22933080542096762, 3.1086244689504383e-15, ...
#        rat_20170523_E1_LH2_cell1 all      (0.12965664334891533, 9.972688787107664e-06, 434)
#
#                                                                         partition_asymmetry  \
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 all      (0.19734501653395728, 1.1009742006962142e-09, ...
#        rat_20160914_E1_LH4_cell1 all      (0.16148946343795895, 6.375745065234639e-07, 437)
#        rat_P16_S1_RH3_20140129   all       (0.3273459623083683, 7.771561172376096e-16, 196)
#        rat_20170523_E1_LH2_cell1 all       (0.2645009892789767, 2.733124837561718e-11, 211)
#
#                                                                               segment_radii
# mtype  filename                  neurite
# L5_TPC rat_20160906_E1_LH5_cell2 all      (0.13273808275444554, 6.49544887710271e-238, 1...
#        rat_20160914_E1_LH4_cell1 all      (0.055065160354490716, 3.785290696889876e-43, ...
#        rat_P16_S1_RH3_20140129   all                      (0.16736980289520653, 0.0, 32077)
#        rat_20170523_E1_LH2_cell1 all                      (0.26554088371933027, 0.0, 31331)   @@@@@@@@
# Empty DataFrame
# Columns: []
# Index: []
